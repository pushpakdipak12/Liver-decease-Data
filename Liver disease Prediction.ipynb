# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Liver_disease_data.csv")
df.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
df.shape
# Out:
# (1700, 11)

# %%
df.isna().sum()
# Out:
# Age                   0
# Gender                0
# BMI                   0
# AlcoholConsumption    0
# Smoking               0
# GeneticRisk           0
# PhysicalActivity      0
# Diabetes              0
# Hypertension          0
# LiverFunctionTest     0
# Diagnosis             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1700 non-null   int64
#  1   Gender              1700 non-null   int64
#  2   BMI                 1700 non-null   float64
#  3   AlcoholConsumption  1700 non-null   float64
#  4   Smoking             1700 non-null   int64
#  5   GeneticRisk         1700 non-null   int64
#  6   PhysicalActivity    1700 non-null   float64
#  7   Diabetes            1700 non-null   int64
#  8   Hypertension        1700 non-null   int64
#  9   LiverFunctionTest   1700 non-null   float64
#  10  Diagnosis           1700 non-null   int64
# dtypes: float64(4), int64(7)
# memory usage: 146.2 KB

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'AlcoholConsumption', 'Smoking', 'GeneticRisk',
#        'PhysicalActivity', 'Diabetes', 'Hypertension', 'LiverFunctionTest',
#        'Diagnosis'],
#       dtype='object')

# %%
columns = [
    'Age', 'AlcoholConsumption', 'BMI', 'PhysicalActivity', 
    'LiverFunctionTest'
]

# Create a subplot layout
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Boxplots for Selected Numerical Columns', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot boxplots for each specified column
for ax, col in zip(axes, columns):
    sns.boxplot(data=df[col], ax=ax)
    ax.set_title(col)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
columns = [
    'Age', 'AlcoholConsumption', 'BMI', 'PhysicalActivity', 
    'LiverFunctionTest'
]

# Create a subplot layout
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Histograms for Selected Numerical Columns', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot histograms for each specified column
for ax, col in zip(axes, columns):
    sns.histplot(data=df[col], ax=ax, kde=True)
    ax.set_title(col)

# Hide the unused subplot
for ax in axes[len(columns):]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'AlcoholConsumption', 'Smoking', 'GeneticRisk',
#        'PhysicalActivity', 'Diabetes', 'Hypertension', 'LiverFunctionTest',
#        'Diagnosis'],
#       dtype='object')

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender',data=df)
plt.title('Count of Gender')
plt.show()

# %%
df.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
columns = [
    'Gender', 'Smoking', 'GeneticRisk', 'Diabetes', 
    'Hypertension', 'Diagnosis'
]

# Create a subplot layout
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Count for Selected Categorical Columns', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot count plots for each specified column
for ax, col in zip(axes, columns):
    sns.countplot(data=df, x=col, ax=ax)
    ax.set_title(col)

# Hide the unused subplot if there are any
for ax in axes[len(columns):]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
df.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
X=df.drop('Diagnosis',axis=1)
y=df['Diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=32)
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8441176470588235

# %%
report = classification_report(y_test, y_pred)
print(f'Report: {report}')
# Out:
# Report:               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       147
#            1       0.85      0.88      0.87       193
#
#     accuracy                           0.84       340
#    macro avg       0.84      0.84      0.84       340
# weighted avg       0.84      0.84      0.84       340

# %%
from sklearn.ensemble import RandomForestClassifier
model2=RandomForestClassifier()
model2.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2=model2.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred2)
print(f'Accuracy: {accuracy}')

# Print classification report
report = classification_report(y_test, y_pred2)
print(report)
# Out:
# Accuracy: 0.8794117647058823
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       147
#            1       0.90      0.89      0.89       193
#
#     accuracy                           0.88       340
#    macro avg       0.88      0.88      0.88       340
# weighted avg       0.88      0.88      0.88       340

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_train_Scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

model=SVC(kernel='linear',random_state=42)
model.fit(X_train_Scaled,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Print classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81       147
#            1       0.87      0.83      0.85       193
#
#     accuracy                           0.84       340
#    macro avg       0.83      0.84      0.83       340
# weighted avg       0.84      0.84      0.84       340

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model.fit(X_train_Scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Train the model
model.fit(X_train_Scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Print classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       147
#            1       0.86      0.82      0.84       193
#
#     accuracy                           0.82       340
#    macro avg       0.82      0.82      0.82       340
# weighted avg       0.83      0.82      0.82       340

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(units=64,activation="relu",input_shape=(X_train_Scaled.shape[1],)))
model.add(Dense(units=64,activation='relu'))

model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train_Scaled,y_train,epochs=100,batch_size=32,validation_split=0.1)
# Out:
# Epoch 1/100
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6113 - loss: 0.6461 - val_accuracy: 0.7721 - val_loss: 0.4997
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8090 - loss: 0.4801 - val_accuracy: 0.8015 - val_loss: 0.4124
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8292 - loss: 0.4003 - val_accuracy: 0.7941 - val_loss: 0.3913
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8374 - loss: 0.4060 - val_accuracy: 0.7941 - val_loss: 0.3858
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8357 - loss: 0.4103 - val_accuracy: 0.8015 - val_loss: 0.3854
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.3545 - val_accuracy: 0.8088 - val_loss: 0.3890
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8341 - loss: 0.3690 - val_accuracy: 0.8088 - val_loss: 0.3841
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8532 - loss: 0.3598 - val_accuracy: 0.8235 - val_loss: 0.3821
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9997 - loss: 0.0150 - val_accuracy: 0.8603 - val_loss: 0.6325
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.8676 - val_loss: 0.6596
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0188 - val_accuracy: 0.8456 - val_loss: 0.6502
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0179 - val_accuracy: 0.8750 - val_loss: 0.6311
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0171 - val_accuracy: 0.8603 - val_loss: 0.6530
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9974 - loss: 0.0163 - val_accuracy: 0.8603 - val_loss: 0.6662
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9998 - loss: 0.0167 - val_accuracy: 0.8529 - val_loss: 0.6396
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0151 - val_accuracy: 0.8529 - val_loss: 0.6750
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0167 - val_accuracy: 0.8529 - val_loss: 0.6448
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.8529 - val_loss: 0.6435
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0141 - val_accuracy: 0.8529 - val_loss: 0.6702
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8603 - val_loss: 0.6535
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0136 - val_accuracy: 0.8529 - val_loss: 0.6556
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.8603 - val_loss: 0.6661
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9986 - loss: 0.0145 - val_accuracy: 0.8529 - val_loss: 0.6704
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9993 - loss: 0.0137 - val_accuracy: 0.8676 - val_loss: 0.6496
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0138 - val_accuracy: 0.8529 - val_loss: 0.7033
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0157 - val_accuracy: 0.8529 - val_loss: 0.6905

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'AlcoholConsumption', 'Smoking', 'GeneticRisk',
#        'PhysicalActivity', 'Diabetes', 'Hypertension', 'LiverFunctionTest',
#        'Diagnosis'],
#       dtype='object')

# %%
predictions = model.predict(X_test_scaled)

# Convert probabilities to class labels (0 or 1)
predicted_classes = (predictions > 0.5).astype("int32").ravel()

# Display predictions
for i, (true_label, predicted_label) in enumerate(zip(y_test, predicted_classes)):
    print(f'Sample {i+1} - True: {true_label}, Predicted: {predicted_label}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Sample 1 - True: 0, Predicted: 0
# Sample 2 - True: 0, Predicted: 0
# Sample 3 - True: 0, Predicted: 1
# Sample 4 - True: 1, Predicted: 1
# Sample 5 - True: 1, Predicted: 0
# Sample 6 - True: 1, Predicted: 0
# Sample 7 - True: 0, Predicted: 0
# Sample 8 - True: 1, Predicted: 1
# Sample 9 - True: 1, Predicted: 1
# Sample 10 - True: 1, Predicted: 0
# Sample 11 - True: 0, Predicted: 0
# Sample 12 - True: 1, Predicted: 1
# Sample 13 - True: 0, Predicted: 0
# Sample 14 - True: 1, Predicted: 1
# Sample 15 - True: 1, Predicted: 1
# Sample 16 - True: 0, Predicted: 0
# Sample 17 - True: 1, Predicted: 0
# Sample 18 - True: 1, Predicted: 1
# Sample 19 - True: 1, Predicted: 1
# Sample 20 - True: 0, Predicted: 0
# Sample 21 - True: 1, Predicted: 1
# Sample 22 - True: 0, Predicted: 0
# Sample 23 - True: 1, Predicted: 1
# Sample 24 - True: 0, Predicted: 1
# Sample 25 - True: 1, Predicted: 1
# Sample 26 - True: 1, Predicted: 1
# Sample 27 - True: 1, Predicted: 0
# Sample 28 - True: 0, Predicted: 0
# Sample 29 - True: 0, Predicted: 1
# Sample 30 - True: 0, Predicted: 0
# Sample 31 - True: 1, Predicted: 1
# Sample 32 - True: 1, Predicted: 1
# Sample 33 - True: 1, Predicted: 0
# Sample 34 - True: 0, Predicted: 0
# Sample 35 - True: 1, Predicted: 1
# Sample 36 - True: 1, Predicted: 1
# Sample 37 - True: 1, Predicted: 1
# Sample 38 - True: 0, Predicted: 0
# Sample 39 - True: 1, Predicted: 1
# Sample 40 - True: 1, Predicted: 1
# Sample 41 - True: 1, Predicted: 1
# Sample 42 - True: 0, Predicted: 0
# Sample 43 - True: 1, Predicted: 1
# Sample 44 - True: 0, Predicted: 0
# Sample 45 - True: 1, Predicted: 0
# Sample 46 - True: 1, Predicted: 0
# Sample 47 - True: 0, Predicted: 1
# Sample 48 - True: 0, Predicted: 1
# Sample 49 - True: 0, Predicted: 1
# Sample 50 - True: 1, Predicted: 1
# Sample 51 - True: 1, Predicted: 1
# Sample 52 - True: 1, Predicted: 1
# Sample 53 - True: 0, Predicted: 0
# Sample 54 - True: 0, Predicted: 0
# Sample 55 - True: 1, Predicted: 1
# Sample 56 - True: 1, Predicted: 1
# Sample 57 - True: 1, Predicted: 0
# Sample 58 - True: 0, Predicted: 1
# Sample 59 - True: 1, Predicted: 0
# Sample 60 - True: 1, Predicted: 1
# Sample 61 - True: 1, Predicted: 1
# Sample 62 - True: 0, Predicted: 1
# Sample 63 - True: 1, Predicted: 1
# Sample 64 - True: 1, Predicted: 1
# Sample 65 - True: 0, Predicted: 0
# Sample 66 - True: 0, Predicted: 0
# Sample 67 - True: 1, Predicted: 1
# Sample 68 - True: 1, Predicted: 0
# Sample 69 - True: 0, Predicted: 0
# Sample 70 - True: 0, Predicted: 0
# Sample 71 - True: 0, Predicted: 0
# Sample 72 - True: 1, Predicted: 1
# Sample 73 - True: 1, Predicted: 1
# Sample 74 - True: 1, Predicted: 1
# Sample 75 - True: 0, Predicted: 0
# Sample 76 - True: 1, Predicted: 1
# Sample 77 - True: 1, Predicted: 1
# Sample 78 - True: 1, Predicted: 1
# Sample 79 - True: 0, Predicted: 0
# Sample 80 - True: 1, Predicted: 1
# Sample 81 - True: 1, Predicted: 1
# Sample 82 - True: 1, Predicted: 1
# Sample 83 - True: 0, Predicted: 0
# Sample 84 - True: 1, Predicted: 0
# Sample 85 - True: 1, Predicted: 1
# Sample 86 - True: 1, Predicted: 1
# Sample 87 - True: 0, Predicted: 0
# Sample 88 - True: 1, Predicted: 1
# Sample 89 - True: 1, Predicted: 1
# Sample 90 - True: 1, Predicted: 1
# Sample 91 - True: 1, Predicted: 1
# Sample 92 - True: 0, Predicted: 1
# Sample 93 - True: 0, Predicted: 1
# Sample 94 - True: 0, Predicted: 0
# Sample 95 - True: 0, Predicted: 0
# Sample 96 - True: 1, Predicted: 1
# Sample 97 - True: 1, Predicted: 1
# Sample 98 - True: 1, Predicted: 1
# Sample 99 - True: 1, Predicted: 1
# Sample 100 - True: 0, Predicted: 0
# Sample 101 - True: 0, Predicted: 0
# Sample 102 - True: 0, Predicted: 0
# Sample 103 - True: 1, Predicted: 1
# Sample 104 - True: 1, Predicted: 1
# Sample 105 - True: 0, Predicted: 0
# Sample 106 - True: 0, Predicted: 0
# Sample 107 - True: 0, Predicted: 0
# Sample 108 - True: 0, Predicted: 0
# Sample 109 - True: 0, Predicted: 1
# Sample 110 - True: 1, Predicted: 1
# Sample 111 - True: 1, Predicted: 1
# Sample 112 - True: 1, Predicted: 1
# Sample 113 - True: 0, Predicted: 0
# Sample 114 - True: 1, Predicted: 1
# Sample 115 - True: 1, Predicted: 0
# Sample 116 - True: 0, Predicted: 0
# Sample 117 - True: 1, Predicted: 1
# Sample 118 - True: 0, Predicted: 0
# Sample 119 - True: 0, Predicted: 0
# Sample 120 - True: 1, Predicted: 1
# Sample 121 - True: 0, Predicted: 0
# Sample 122 - True: 1, Predicted: 1
# Sample 123 - True: 1, Predicted: 1
# Sample 124 - True: 1, Predicted: 1
# Sample 125 - True: 1, Predicted: 1
# Sample 126 - True: 1, Predicted: 1
# Sample 127 - True: 1, Predicted: 1
# Sample 128 - True: 0, Predicted: 0
# Sample 129 - True: 1, Predicted: 0
# Sample 130 - True: 1, Predicted: 1
# Sample 131 - True: 1, Predicted: 1
# Sample 132 - True: 0, Predicted: 0
# Sample 133 - True: 1, Predicted: 1
# Sample 134 - True: 1, Predicted: 1
# Sample 135 - True: 1, Predicted: 0
# Sample 136 - True: 1, Predicted: 1
# Sample 137 - True: 1, Predicted: 1
# Sample 138 - True: 0, Predicted: 0
# Sample 139 - True: 1, Predicted: 1
# Sample 140 - True: 0, Predicted: 0
# Sample 141 - True: 1, Predicted: 1
# Sample 142 - True: 1, Predicted: 1
# Sample 143 - True: 0, Predicted: 0
# Sample 144 - True: 1, Predicted: 1
# Sample 145 - True: 0, Predicted: 0
# Sample 146 - True: 0, Predicted: 0
# Sample 147 - True: 1, Predicted: 1
# Sample 148 - True: 1, Predicted: 0
# Sample 149 - True: 0, Predicted: 0
# Sample 150 - True: 0, Predicted: 0
# Sample 151 - True: 1, Predicted: 1
# Sample 152 - True: 1, Predicted: 1
# Sample 153 - True: 1, Predicted: 1
# Sample 154 - True: 0, Predicted: 1
# Sample 155 - True: 0, Predicted: 0
# Sample 156 - True: 0, Predicted: 0
# Sample 157 - True: 1, Predicted: 1
# Sample 158 - True: 0, Predicted: 0
# Sample 159 - True: 1, Predicted: 1
# Sample 160 - True: 0, Predicted: 0
# Sample 161 - True: 0, Predicted: 0
# Sample 162 - True: 0, Predicted: 0
# Sample 163 - True: 0, Predicted: 0
# Sample 164 - True: 1, Predicted: 1
# Sample 165 - True: 1, Predicted: 1
# Sample 166 - True: 1, Predicted: 1
# Sample 167 - True: 1, Predicted: 1
# Sample 168 - True: 0, Predicted: 0
# Sample 169 - True: 0, Predicted: 0
# Sample 170 - True: 1, Predicted: 1
# Sample 171 - True: 0, Predicted: 0
# Sample 172 - True: 1, Predicted: 1
# Sample 173 - True: 0, Predicted: 0
# Sample 174 - True: 1, Predicted: 0
# Sample 175 - True: 0, Predicted: 0
# Sample 176 - True: 1, Predicted: 1
# Sample 177 - True: 1, Predicted: 1
# Sample 178 - True: 1, Predicted: 1
# Sample 179 - True: 0, Predicted: 0
# Sample 180 - True: 0, Predicted: 0
# Sample 181 - True: 0, Predicted: 0
# Sample 182 - True: 1, Predicted: 1
# Sample 183 - True: 1, Predicted: 1
# Sample 184 - True: 1, Predicted: 1
# Sample 185 - True: 1, Predicted: 0
# Sample 186 - True: 0, Predicted: 0
# Sample 187 - True: 1, Predicted: 1
# Sample 188 - True: 1, Predicted: 1
# Sample 189 - True: 1, Predicted: 1
# Sample 190 - True: 0, Predicted: 0
# Sample 191 - True: 1, Predicted: 0
# Sample 192 - True: 0, Predicted: 0
# Sample 193 - True: 1, Predicted: 1
# Sample 194 - True: 1, Predicted: 0
# Sample 195 - True: 1, Predicted: 1
# Sample 196 - True: 0, Predicted: 0
# Sample 197 - True: 0, Predicted: 0
# Sample 198 - True: 1, Predicted: 1
# Sample 199 - True: 0, Predicted: 0
# Sample 200 - True: 1, Predicted: 0
# Sample 201 - True: 1, Predicted: 1
# Sample 202 - True: 0, Predicted: 0
# Sample 203 - True: 1, Predicted: 1
# Sample 204 - True: 1, Predicted: 1
# Sample 205 - True: 1, Predicted: 1
# Sample 206 - True: 0, Predicted: 0
# Sample 207 - True: 0, Predicted: 0
# Sample 208 - True: 0, Predicted: 0
# Sample 209 - True: 0, Predicted: 0
# Sample 210 - True: 0, Predicted: 0
# Sample 211 - True: 1, Predicted: 1
# Sample 212 - True: 1, Predicted: 1
# Sample 213 - True: 0, Predicted: 0
# Sample 214 - True: 1, Predicted: 1
# Sample 215 - True: 0, Predicted: 0
# Sample 216 - True: 1, Predicted: 1
# Sample 217 - True: 1, Predicted: 0
# Sample 218 - True: 1, Predicted: 1
# Sample 219 - True: 1, Predicted: 1
# Sample 220 - True: 0, Predicted: 0
# Sample 221 - True: 0, Predicted: 0
# Sample 222 - True: 1, Predicted: 1
# Sample 223 - True: 1, Predicted: 1
# Sample 224 - True: 1, Predicted: 1
# Sample 225 - True: 1, Predicted: 0
# Sample 226 - True: 0, Predicted: 0
# Sample 227 - True: 1, Predicted: 1
# Sample 228 - True: 0, Predicted: 0
# Sample 229 - True: 1, Predicted: 1
# Sample 230 - True: 0, Predicted: 0
# Sample 231 - True: 0, Predicted: 1
# Sample 232 - True: 1, Predicted: 1
# Sample 233 - True: 1, Predicted: 1
# Sample 234 - True: 0, Predicted: 0
# Sample 235 - True: 1, Predicted: 1
# Sample 236 - True: 1, Predicted: 0
# Sample 237 - True: 0, Predicted: 0
# Sample 238 - True: 0, Predicted: 0
# Sample 239 - True: 1, Predicted: 1
# Sample 240 - True: 0, Predicted: 0
# Sample 241 - True: 0, Predicted: 0
# Sample 242 - True: 1, Predicted: 1
# Sample 243 - True: 1, Predicted: 1
# Sample 244 - True: 1, Predicted: 1
# Sample 245 - True: 1, Predicted: 1
# Sample 246 - True: 0, Predicted: 0
# Sample 247 - True: 1, Predicted: 1
# Sample 248 - True: 1, Predicted: 0
# Sample 249 - True: 0, Predicted: 1
# Sample 250 - True: 1, Predicted: 1
# Sample 251 - True: 0, Predicted: 0
# Sample 252 - True: 1, Predicted: 1
# Sample 253 - True: 0, Predicted: 0
# Sample 254 - True: 0, Predicted: 0
# Sample 255 - True: 1, Predicted: 1
# Sample 256 - True: 1, Predicted: 1
# Sample 257 - True: 0, Predicted: 0
# Sample 258 - True: 0, Predicted: 0
# Sample 259 - True: 1, Predicted: 1
# Sample 260 - True: 0, Predicted: 0
# Sample 261 - True: 0, Predicted: 0
# Sample 262 - True: 0, Predicted: 1
# Sample 263 - True: 0, Predicted: 0
# Sample 264 - True: 1, Predicted: 1
# Sample 265 - True: 1, Predicted: 1
# Sample 266 - True: 1, Predicted: 1
# Sample 267 - True: 1, Predicted: 1
# Sample 268 - True: 1, Predicted: 1
# Sample 269 - True: 0, Predicted: 0
# Sample 270 - True: 0, Predicted: 0
# Sample 271 - True: 1, Predicted: 1
# Sample 272 - True: 1, Predicted: 1
# Sample 273 - True: 0, Predicted: 0
# Sample 274 - True: 1, Predicted: 1
# Sample 275 - True: 0, Predicted: 0
# Sample 276 - True: 1, Predicted: 0
# Sample 277 - True: 0, Predicted: 0
# Sample 278 - True: 1, Predicted: 1
# Sample 279 - True: 0, Predicted: 0
# Sample 280 - True: 1, Predicted: 1
# Sample 281 - True: 0, Predicted: 0
# Sample 282 - True: 1, Predicted: 1
# Sample 283 - True: 1, Predicted: 1
# Sample 284 - True: 1, Predicted: 1
# Sample 285 - True: 0, Predicted: 0
# Sample 286 - True: 0, Predicted: 0
# Sample 287 - True: 1, Predicted: 1
# Sample 288 - True: 1, Predicted: 0
# Sample 289 - True: 0, Predicted: 0
# Sample 290 - True: 1, Predicted: 1
# Sample 291 - True: 0, Predicted: 1
# Sample 292 - True: 0, Predicted: 1
# Sample 293 - True: 1, Predicted: 0
# Sample 294 - True: 1, Predicted: 1
# Sample 295 - True: 0, Predicted: 0
# Sample 296 - True: 1, Predicted: 1
# Sample 297 - True: 0, Predicted: 0
# Sample 298 - True: 0, Predicted: 0
# Sample 299 - True: 0, Predicted: 0
# Sample 300 - True: 1, Predicted: 1
# Sample 301 - True: 0, Predicted: 0
# Sample 302 - True: 1, Predicted: 1
# Sample 303 - True: 1, Predicted: 1
# Sample 304 - True: 0, Predicted: 0
# Sample 305 - True: 0, Predicted: 0
# Sample 306 - True: 0, Predicted: 1
# Sample 307 - True: 0, Predicted: 0
# Sample 308 - True: 0, Predicted: 0
# Sample 309 - True: 0, Predicted: 0
# Sample 310 - True: 0, Predicted: 0
# Sample 311 - True: 0, Predicted: 0
# Sample 312 - True: 1, Predicted: 1
# Sample 313 - True: 0, Predicted: 1
# Sample 314 - True: 0, Predicted: 0
# Sample 315 - True: 1, Predicted: 1
# Sample 316 - True: 0, Predicted: 0
# Sample 317 - True: 1, Predicted: 0
# Sample 318 - True: 1, Predicted: 1
# Sample 319 - True: 1, Predicted: 1
# Sample 320 - True: 1, Predicted: 1
# Sample 321 - True: 1, Predicted: 0
# Sample 322 - True: 0, Predicted: 0
# Sample 323 - True: 1, Predicted: 1
# Sample 324 - True: 1, Predicted: 1
# Sample 325 - True: 0, Predicted: 1
# Sample 326 - True: 1, Predicted: 0
# Sample 327 - True: 0, Predicted: 0
# Sample 328 - True: 0, Predicted: 0
# Sample 329 - True: 1, Predicted: 1
# Sample 330 - True: 0, Predicted: 0
# Sample 331 - True: 1, Predicted: 1
# Sample 332 - True: 1, Predicted: 0
# Sample 333 - True: 1, Predicted: 1
# Sample 334 - True: 1, Predicted: 0
# Sample 335 - True: 0, Predicted: 0
# Sample 336 - True: 0, Predicted: 0
# Sample 337 - True: 1, Predicted: 1
# Sample 338 - True: 1, Predicted: 1
# Sample 339 - True: 1, Predicted: 1
# Sample 340 - True: 0, Predicted: 0
